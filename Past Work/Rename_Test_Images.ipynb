# %% [markdown]
# Original test images have randomized hexadecimal names. A copy of the test images must be made to a separate directory while maintaining the same order of image files based on their entries in the Kaggle spreadsheet submission entry.
#
# This is to facilitate the loading of images by the dataloader for the neural network, which requires all file names to be the same, ending only with different index numbers.
#
# Upon prediction, the list of predicted classes can then be inserted as an excel column into the kaggle spreadsheet submission entry alongside the other column of original image names.
#
# **Indexes for Image Classes:**
# 0. Black-grass
# 1. Charlock
# 2. Cleavers
# 3. Common Chickweed
# 4. Common Wheat
# 5. Fat Hen
# 6. Loose Silky-bent
# 7. Maize
# 8. Scentless Mayweed
# 9. Shepherd's Purse
# 10. Small-flowered Cranesbill
# 11. Sugar Beet

# %%
# Mount google drive to notebook.
from google.colab import drive
drive.mount('/content/drive/')

# To force remounting google drive to notebook.
#drive.mount('/content/drive', force_remount = True)

# Dismount google drive from notebook.
#drive.flush_and_unmount()

# Ensure we are in the correct working directory.
# %cd /content/drive/MyDrive/CX4041-Group-Project/
# %ls\
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/CX4041-Group-Project
#  Checkpoint/
#  CNN.ipynb
# 'CX4041 Group Project Report.docx'
#  EfficientNet_predicted_species.xlsx
#  Ensemble_predicted_species.xlsx
#  InceptionResNetV2_predicted_species.xlsx
#  InceptionV3_predicted_species.xlsx
#  kNN.ipynb
#  Model-Figures/
#  Original_Test_Plant_Images/
#  Preprocessed_Test_Images/
#  Preprocessed_Train_Images/
#  Preprocessing_Train_Images.ipynb
#  Preprocess_Masking_Train_Test_Images.ipynb
#  Preprocess_Rename_Test_Images.ipynb
#  Renamed_Test_Plant_Images/
#  ResNet50_predicted_species.xlsx
#  Submission_Sample.xlsx
#  Test_Ensemble.ipynb
# 'Test Images No Mask'/
#  Train_Test_EfficientNet.ipynb
#  Train_Test_InceptionResNetV2.ipynb
#  Train_Test_InceptionV3.ipynb
#  Train_Test_ResNet50.ipynb
#  Train_Test_VGG16.ipynb
#  Train_Test_Xception.ipynb
#  VGG16_predicted_species.xlsx
# '[Video Presentation] StoryBoard & Script.gdoc'
#  Xception_predicted_species.xlsx

# %%
# Import the required libraries.
import os
import shutil
import pandas

# %%
# Specify the path to the excel file and the sheet name to retrieve.
excel_file_path = '/content/drive/MyDrive/CX4041-Group-Project/Submission_Sample.xlsx'
excel_sheet_name = 'Submission Sample'
test_images_list = []

# Read in the excel file and extract the values in the first column.
test_images_dataframe = pandas.ExcelFile(excel_file_path).parse(excel_sheet_name)

# Append all the test image names in the selected column of the dataframe into a list.
for image_name in test_images_dataframe['file']:
  test_images_list.append(image_name)

# %%
# Specify the source and destination directory. Test images must be in its own subdirectory to be properly read by the dataloader.
source_directory = '/content/drive/MyDrive/CX4041-Group-Project/Original_Test_Images/'
destination_directory = '/content/drive/MyDrive/CX4041-Group-Project/Renamed_Test_Images/test/'

# Create a subdirectory for all the renamed test images if it does not exist.
if not os.path.isdir(destination_directory):
  os.makedirs(destination_directory)

# %%
# Starting index and the base name for renaming of test files.
index = 1
name = 'test_'

# For each image name in the list of test image names.
for image_name in test_images_list:

  # Locate the image in the source directory and copy it to the destination directory.
  shutil.copy(source_directory + image_name, destination_directory)

  # Construct the new file name for the test image.
  new_test_image_name =  name + str(index)

  # Rename the most recently copied test image.
  os.rename(destination_directory + image_name, destination_directory + new_test_image_name)

  # Increment the index for the renamed image.
  index += 1
  print('Processed image:', new_test_image_name)
# Out:
# Processed image: test_1
# Processed image: test_2
# Processed image: test_3
# Processed image: test_4
# Processed image: test_5
# Processed image: test_6
# Processed image: test_7
# Processed image: test_8
# Processed image: test_9
# Processed image: test_10
# Processed image: test_11
# Processed image: test_12
# Processed image: test_13
# Processed image: test_14
# Processed image: test_15
# Processed image: test_16
# Processed image: test_17
# Processed image: test_18
# Processed image: test_19
# Processed image: test_20
# Processed image: test_21
# Processed image: test_22
# Processed image: test_23
# Processed image: test_24
# Processed image: test_25
# Processed image: test_26
# Processed image: test_27
# Processed image: test_28
# Processed image: test_29
# Processed image: test_30
# Processed image: test_31
# Processed image: test_32
# Processed image: test_33
# Processed image: test_34
# Processed image: test_35
# Processed image: test_36
# Processed image: test_37
# Processed image: test_38
# Processed image: test_39
# Processed image: test_40
# Processed image: test_41
# Processed image: test_42
# Processed image: test_43
# Processed image: test_44
# Processed image: test_45
# Processed image: test_46
# Processed image: test_47
# Processed image: test_48
# Processed image: test_49
# Processed image: test_50
# Processed image: test_51
# Processed image: test_52
# Processed image: test_53
# Processed image: test_54
# Processed image: test_55
# Processed image: test_56
# Processed image: test_57
# Processed image: test_58
# Processed image: test_59
# Processed image: test_60
# Processed image: test_61
# Processed image: test_62
# Processed image: test_63
# Processed image: test_64
# Processed image: test_65
# Processed image: test_66
# Processed image: test_67
# Processed image: test_68
# Processed image: test_69
# Processed image: test_70
# Processed image: test_71
# Processed image: test_72
# Processed image: test_73
# Processed image: test_74
# Processed image: test_75
# Processed image: test_76
# Processed image: test_77
# Processed image: test_78
# Processed image: test_79
# Processed image: test_80
# Processed image: test_81
# Processed image: test_82
# Processed image: test_83
# Processed image: test_84
# Processed image: test_85
# Processed image: test_86
# Processed image: test_87
# Processed image: test_88
# Processed image: test_89
# Processed image: test_90
# Processed image: test_91
# Processed image: test_92
# Processed image: test_93
# Processed image: test_94
# Processed image: test_95
# Processed image: test_96
# Processed image: test_97
# Processed image: test_98
# Processed image: test_99
# Processed image: test_100
# Processed image: test_101
# Processed image: test_102
# Processed image: test_103
# Processed image: test_104
# Processed image: test_105
# Processed image: test_106
# Processed image: test_107
# Processed image: test_108
# Processed image: test_109
# Processed image: test_110
# Processed image: test_111
# Processed image: test_112
# Processed image: test_113
# Processed image: test_114
# Processed image: test_115
# Processed image: test_116
# Processed image: test_117
# Processed image: test_118
# Processed image: test_119
# Processed image: test_120
# Processed image: test_121
# Processed image: test_122
# Processed image: test_123
# Processed image: test_124
# Processed image: test_125
# Processed image: test_126
# Processed image: test_127
# Processed image: test_128
# Processed image: test_129
# Processed image: test_130
# Processed image: test_131
# Processed image: test_132
# Processed image: test_133
# Processed image: test_134
# Processed image: test_135
# Processed image: test_136
# Processed image: test_137
# Processed image: test_138
# Processed image: test_139
# Processed image: test_140
# Processed image: test_141
# Processed image: test_142
# Processed image: test_143
# Processed image: test_144
# Processed image: test_145
# Processed image: test_146
# Processed image: test_147
# Processed image: test_148
# Processed image: test_149
# Processed image: test_150
# Processed image: test_151
# Processed image: test_152
# Processed image: test_153
# Processed image: test_154
# Processed image: test_155
# Processed image: test_156
# Processed image: test_157
# Processed image: test_158
# Processed image: test_159
# Processed image: test_160
# Processed image: test_161
# Processed image: test_162
# Processed image: test_163
# Processed image: test_164
# Processed image: test_165
# Processed image: test_166
# Processed image: test_167
# Processed image: test_168
# Processed image: test_169
# Processed image: test_170
# Processed image: test_171
# Processed image: test_172
# Processed image: test_173
# Processed image: test_174
# Processed image: test_175
# Processed image: test_176
# Processed image: test_177
# Processed image: test_178
# Processed image: test_179
# Processed image: test_180
# Processed image: test_181
# Processed image: test_182
# Processed image: test_183
# Processed image: test_184
# Processed image: test_185
# Processed image: test_186
# Processed image: test_187
# Processed image: test_188
# Processed image: test_189
# Processed image: test_190
# Processed image: test_191
# Processed image: test_192
# Processed image: test_193
# Processed image: test_194
# Processed image: test_195
# Processed image: test_196
# Processed image: test_197
# Processed image: test_198
# Processed image: test_199
# Processed image: test_200
# Processed image: test_201
# Processed image: test_202
# Processed image: test_203
# Processed image: test_204
# Processed image: test_205
# Processed image: test_206
# Processed image: test_207
# Processed image: test_208
# Processed image: test_209
# Processed image: test_210
# Processed image: test_211
# Processed image: test_212
# Processed image: test_213
# Processed image: test_214
# Processed image: test_215
# Processed image: test_216
# Processed image: test_217
# Processed image: test_218
# Processed image: test_219
# Processed image: test_220
# Processed image: test_221
# Processed image: test_222
# Processed image: test_223
# Processed image: test_224
# Processed image: test_225
# Processed image: test_226
# Processed image: test_227
# Processed image: test_228
# Processed image: test_229
# Processed image: test_230
# Processed image: test_231
# Processed image: test_232
# Processed image: test_233
# Processed image: test_234
# Processed image: test_235
# Processed image: test_236
# Processed image: test_237
# Processed image: test_238
# Processed image: test_239
# Processed image: test_240
# Processed image: test_241
# Processed image: test_242
# Processed image: test_243
# Processed image: test_244
# Processed image: test_245
# Processed image: test_246
# Processed image: test_247
# Processed image: test_248
# Processed image: test_249
# Processed image: test_250
# Processed image: test_251
# Processed image: test_252
# Processed image: test_253
# Processed image: test_254
# Processed image: test_255
# Processed image: test_256
# Processed image: test_257
# Processed image: test_258
# Processed image: test_259
# Processed image: test_260
# Processed image: test_261
# Processed image: test_262
# Processed image: test_263
# Processed image: test_264
# Processed image: test_265
# Processed image: test_266
# Processed image: test_267
# Processed image: test_268
# Processed image: test_269
# Processed image: test_270
# Processed image: test_271
# Processed image: test_272
# Processed image: test_273
# Processed image: test_274
# Processed image: test_275
# Processed image: test_276
# Processed image: test_277
# Processed image: test_278
# Processed image: test_279
# Processed image: test_280
# Processed image: test_281
# Processed image: test_282
# Processed image: test_283
# Processed image: test_284
# Processed image: test_285
# Processed image: test_286
# Processed image: test_287
# Processed image: test_288
# Processed image: test_289
# Processed image: test_290
# Processed image: test_291
# Processed image: test_292
# Processed image: test_293
# Processed image: test_294
# Processed image: test_295
# Processed image: test_296
# Processed image: test_297
# Processed image: test_298
# Processed image: test_299
# Processed image: test_300
# Processed image: test_301
# Processed image: test_302
# Processed image: test_303
# Processed image: test_304
# Processed image: test_305
# Processed image: test_306
# Processed image: test_307
# Processed image: test_308
# Processed image: test_309
# Processed image: test_310
# Processed image: test_311
# Processed image: test_312
# Processed image: test_313
# Processed image: test_314
# Processed image: test_315
# Processed image: test_316
# Processed image: test_317
# Processed image: test_318
# Processed image: test_319
# Processed image: test_320
# Processed image: test_321
# Processed image: test_322
# Processed image: test_323
# Processed image: test_324
# Processed image: test_325
# Processed image: test_326
# Processed image: test_327
# Processed image: test_328
# Processed image: test_329
# Processed image: test_330
# Processed image: test_331
# Processed image: test_332
# Processed image: test_333
# Processed image: test_334
# Processed image: test_335
# Processed image: test_336
# Processed image: test_337
# Processed image: test_338
# Processed image: test_339
# Processed image: test_340
# Processed image: test_341
# Processed image: test_342
# Processed image: test_343
# Processed image: test_344
# Processed image: test_345
# Processed image: test_346
# Processed image: test_347
# Processed image: test_348
# Processed image: test_349
# Processed image: test_350
# Processed image: test_351
# Processed image: test_352
# Processed image: test_353
# Processed image: test_354
# Processed image: test_355
# Processed image: test_356
# Processed image: test_357
# Processed image: test_358
# Processed image: test_359
# Processed image: test_360
# Processed image: test_361
# Processed image: test_362
# Processed image: test_363
# Processed image: test_364
# Processed image: test_365
# Processed image: test_366
# Processed image: test_367
# Processed image: test_368
# Processed image: test_369
# Processed image: test_370
# Processed image: test_371
# Processed image: test_372
# Processed image: test_373
# Processed image: test_374
# Processed image: test_375
# Processed image: test_376
# Processed image: test_377
# Processed image: test_378
# Processed image: test_379
# Processed image: test_380
# Processed image: test_381
# Processed image: test_382
# Processed image: test_383
# Processed image: test_384
# Processed image: test_385
# Processed image: test_386
# Processed image: test_387
# Processed image: test_388
# Processed image: test_389
# Processed image: test_390
# Processed image: test_391
# Processed image: test_392
# Processed image: test_393
# Processed image: test_394
# Processed image: test_395
# Processed image: test_396
# Processed image: test_397
# Processed image: test_398
# Processed image: test_399
# Processed image: test_400
# Processed image: test_401
# Processed image: test_402
# Processed image: test_403
# Processed image: test_404
# Processed image: test_405
# Processed image: test_406
# Processed image: test_407
# Processed image: test_408
# Processed image: test_409
# Processed image: test_410
# Processed image: test_411
# Processed image: test_412
# Processed image: test_413
# Processed image: test_414
# Processed image: test_415
# Processed image: test_416
# Processed image: test_417
# Processed image: test_418
# Processed image: test_419
# Processed image: test_420
# Processed image: test_421
# Processed image: test_422
# Processed image: test_423
# Processed image: test_424
# Processed image: test_425
# Processed image: test_426
# Processed image: test_427
# Processed image: test_428
# Processed image: test_429
# Processed image: test_430
# Processed image: test_431
# Processed image: test_432
# Processed image: test_433
# Processed image: test_434
# Processed image: test_435
# Processed image: test_436
# Processed image: test_437
# Processed image: test_438
# Processed image: test_439
# Processed image: test_440
# Processed image: test_441
# Processed image: test_442
# Processed image: test_443
# Processed image: test_444
# Processed image: test_445
# Processed image: test_446
# Processed image: test_447
# Processed image: test_448
# Processed image: test_449
# Processed image: test_450
# Processed image: test_451
# Processed image: test_452
# Processed image: test_453
# Processed image: test_454
# Processed image: test_455
# Processed image: test_456
# Processed image: test_457
# Processed image: test_458
# Processed image: test_459
# Processed image: test_460
# Processed image: test_461
# Processed image: test_462
# Processed image: test_463
# Processed image: test_464
# Processed image: test_465
# Processed image: test_466
# Processed image: test_467
# Processed image: test_468
# Processed image: test_469
# Processed image: test_470
# Processed image: test_471
# Processed image: test_472
# Processed image: test_473
# Processed image: test_474
# Processed image: test_475
# Processed image: test_476
# Processed image: test_477
# Processed image: test_478
# Processed image: test_479
# Processed image: test_480
# Processed image: test_481
# Processed image: test_482
# Processed image: test_483
# Processed image: test_484
# Processed image: test_485
# Processed image: test_486
# Processed image: test_487
# Processed image: test_488
# Processed image: test_489
# Processed image: test_490
# Processed image: test_491
# Processed image: test_492
# Processed image: test_493
# Processed image: test_494
# Processed image: test_495
# Processed image: test_496
# Processed image: test_497
# Processed image: test_498
# Processed image: test_499
# Processed image: test_500
# Processed image: test_501
# Processed image: test_502
# Processed image: test_503
# Processed image: test_504
# Processed image: test_505
# Processed image: test_506
# Processed image: test_507
# Processed image: test_508
# Processed image: test_509
# Processed image: test_510
# Processed image: test_511
# Processed image: test_512
# Processed image: test_513
# Processed image: test_514
# Processed image: test_515
# Processed image: test_516
# Processed image: test_517
# Processed image: test_518
# Processed image: test_519
# Processed image: test_520
# Processed image: test_521
# Processed image: test_522
# Processed image: test_523
# Processed image: test_524
# Processed image: test_525
# Processed image: test_526
# Processed image: test_527
# Processed image: test_528
# Processed image: test_529
# Processed image: test_530
# Processed image: test_531
# Processed image: test_532
# Processed image: test_533
# Processed image: test_534
# Processed image: test_535
# Processed image: test_536
# Processed image: test_537
# Processed image: test_538
# Processed image: test_539
# Processed image: test_540
# Processed image: test_541
# Processed image: test_542
# Processed image: test_543
# Processed image: test_544
# Processed image: test_545
# Processed image: test_546
# Processed image: test_547
# Processed image: test_548
# Processed image: test_549
# Processed image: test_550
# Processed image: test_551
# Processed image: test_552
# Processed image: test_553
# Processed image: test_554
# Processed image: test_555
# Processed image: test_556
# Processed image: test_557
# Processed image: test_558
# Processed image: test_559
# Processed image: test_560
# Processed image: test_561
# Processed image: test_562
# Processed image: test_563
# Processed image: test_564
# Processed image: test_565
# Processed image: test_566
# Processed image: test_567
# Processed image: test_568
# Processed image: test_569
# Processed image: test_570
# Processed image: test_571
# Processed image: test_572
# Processed image: test_573
# Processed image: test_574
# Processed image: test_575
# Processed image: test_576
# Processed image: test_577
# Processed image: test_578
# Processed image: test_579
# Processed image: test_580
# Processed image: test_581
# Processed image: test_582
# Processed image: test_583
# Processed image: test_584
# Processed image: test_585
# Processed image: test_586
# Processed image: test_587
# Processed image: test_588
# Processed image: test_589
# Processed image: test_590
# Processed image: test_591
# Processed image: test_592
# Processed image: test_593
# Processed image: test_594
# Processed image: test_595
# Processed image: test_596
# Processed image: test_597
# Processed image: test_598
# Processed image: test_599
# Processed image: test_600
# Processed image: test_601
# Processed image: test_602
# Processed image: test_603
# Processed image: test_604
# Processed image: test_605
# Processed image: test_606
# Processed image: test_607
# Processed image: test_608
# Processed image: test_609
# Processed image: test_610
# Processed image: test_611
# Processed image: test_612
# Processed image: test_613
# Processed image: test_614
# Processed image: test_615
# Processed image: test_616
# Processed image: test_617
# Processed image: test_618
# Processed image: test_619
# Processed image: test_620
# Processed image: test_621
# Processed image: test_622
# Processed image: test_623
# Processed image: test_624
# Processed image: test_625
# Processed image: test_626
# Processed image: test_627
# Processed image: test_628
# Processed image: test_629
# Processed image: test_630
# Processed image: test_631
# Processed image: test_632
# Processed image: test_633
# Processed image: test_634
# Processed image: test_635
# Processed image: test_636
# Processed image: test_637
# Processed image: test_638
# Processed image: test_639
# Processed image: test_640
# Processed image: test_641
# Processed image: test_642
# Processed image: test_643
# Processed image: test_644
# Processed image: test_645
# Processed image: test_646
# Processed image: test_647
# Processed image: test_648
# Processed image: test_649
# Processed image: test_650
# Processed image: test_651
# Processed image: test_652
# Processed image: test_653
# Processed image: test_654
# Processed image: test_655
# Processed image: test_656
# Processed image: test_657
# Processed image: test_658
# Processed image: test_659
# Processed image: test_660
# Processed image: test_661
# Processed image: test_662
# Processed image: test_663
# Processed image: test_664
# Processed image: test_665
# Processed image: test_666
# Processed image: test_667
# Processed image: test_668
# Processed image: test_669
# Processed image: test_670
# Processed image: test_671
# Processed image: test_672
# Processed image: test_673
# Processed image: test_674
# Processed image: test_675
# Processed image: test_676
# Processed image: test_677
# Processed image: test_678
# Processed image: test_679
# Processed image: test_680
# Processed image: test_681
# Processed image: test_682
# Processed image: test_683
# Processed image: test_684
# Processed image: test_685
# Processed image: test_686
# Processed image: test_687
# Processed image: test_688
# Processed image: test_689
# Processed image: test_690
# Processed image: test_691
# Processed image: test_692
# Processed image: test_693
# Processed image: test_694
# Processed image: test_695
# Processed image: test_696
# Processed image: test_697
# Processed image: test_698
# Processed image: test_699
# Processed image: test_700
# Processed image: test_701
# Processed image: test_702
# Processed image: test_703
# Processed image: test_704
# Processed image: test_705
# Processed image: test_706
# Processed image: test_707
# Processed image: test_708
# Processed image: test_709
# Processed image: test_710
# Processed image: test_711
# Processed image: test_712
# Processed image: test_713
# Processed image: test_714
# Processed image: test_715
# Processed image: test_716
# Processed image: test_717
# Processed image: test_718
# Processed image: test_719
# Processed image: test_720
# Processed image: test_721
# Processed image: test_722
# Processed image: test_723
# Processed image: test_724
# Processed image: test_725
# Processed image: test_726
# Processed image: test_727
# Processed image: test_728
# Processed image: test_729
# Processed image: test_730
# Processed image: test_731
# Processed image: test_732
# Processed image: test_733
# Processed image: test_734
# Processed image: test_735
# Processed image: test_736
# Processed image: test_737
# Processed image: test_738
# Processed image: test_739
# Processed image: test_740
# Processed image: test_741
# Processed image: test_742
# Processed image: test_743
# Processed image: test_744
# Processed image: test_745
# Processed image: test_746
# Processed image: test_747
# Processed image: test_748
# Processed image: test_749
# Processed image: test_750
# Processed image: test_751
# Processed image: test_752
# Processed image: test_753
# Processed image: test_754
# Processed image: test_755
# Processed image: test_756
# Processed image: test_757
# Processed image: test_758
# Processed image: test_759
# Processed image: test_760
# Processed image: test_761
# Processed image: test_762
# Processed image: test_763
# Processed image: test_764
# Processed image: test_765
# Processed image: test_766
# Processed image: test_767
# Processed image: test_768
# Processed image: test_769
# Processed image: test_770
# Processed image: test_771
# Processed image: test_772
# Processed image: test_773
# Processed image: test_774
# Processed image: test_775
# Processed image: test_776
# Processed image: test_777
# Processed image: test_778
# Processed image: test_779
# Processed image: test_780
# Processed image: test_781
# Processed image: test_782
# Processed image: test_783
# Processed image: test_784
# Processed image: test_785
# Processed image: test_786
# Processed image: test_787
# Processed image: test_788
# Processed image: test_789
# Processed image: test_790
# Processed image: test_791
# Processed image: test_792
# Processed image: test_793
# Processed image: test_794
